# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import StringType, StructType, StructField

# %%
spark = SparkSession.builder.appName("spark").getOrCreate()
# Out:
# 24/02/08 21:26:07 WARN Utils: Your hostname, mieshiii resolves to a loopback address: 127.0.1.1; using 192.168.0.106 instead (on interface wlp3s0)
# 24/02/08 21:26:07 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/02/08 21:26:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import boto3

# %%
s3_client = boto3.client('s3', aws_access_key_id='AKIAS4FCWYW2DLKABQUG', aws_secret_access_key='fLsAdu7WGCCTSxUu+SngXe668ISZ76uLpbOMjB8G')

# %%
response = s3_client.get_object(Bucket='test-etl-bucket-erp', Key='athletes_2.csv')

# %%
reponse2 = s3_client.get_object(Bucket='test-etl-bucket-erp', Key='athletes.csv')

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': 'STDDF4W9GQPK42ZS',
#   'HostId': 'Ewq8HnD6nJ17809G3kWlDDpLLNua+87+K4dCDYuZumoc65cpJtdB+Jx4m1L+YGMK9IFBCU4e9Sg=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Ewq8HnD6nJ17809G3kWlDDpLLNua+87+K4dCDYuZumoc65cpJtdB+Jx4m1L+YGMK9IFBCU4e9Sg=',
#    'x-amz-request-id': 'STDDF4W9GQPK42ZS',
#    'date': 'Thu, 08 Feb 2024 13:37:46 GMT',
#    'last-modified': 'Tue, 06 Feb 2024 13:49:40 GMT',
#    'etag': '"5c6917619b225eecc1c926ab6b898808"',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'binary/octet-stream',
#    'server': 'AmazonS3',
#    'content-length': '407435'},
#   'RetryAttempts': 1},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2024, 2, 6, 13, 49, 40, tzinfo=tzutc()),
#  'ContentLength': 407435,
#  'ETag': '"5c6917619b225eecc1c926ab6b898808"',
#  'ContentType': 'binary/octet-stream',
#  'ServerSideEncryption': 'AES256',
#  'Metadata': {},
# ...

# %%
s3_obj = response['Body'].read().decode('utf-8')

# %%
s3_obj2 = reponse2['Body'].read().decode('utf-8').replace("\r", "")

# %%
s3_obj
# Out:
# 'PersonName,Country,Discipline\nAALERUD Katrine,Norway,Cycling Road\nABAD Nestor,Spain,Artistic Gymnastics\nABAGNALE Giovanni,Italy,Rowing\nABALDE Alberto,Spain,Basketball\nABALDE Tamara,Spain,Basketball\nABALO Luc,France,Handball\nABAROA Cesar,Chile,Rowing\nABASS Abobakr,Sudan,Swimming\nABBASALI Hamideh,Islamic Republic of Iran,Karate\nABBASOV Islam,Azerbaijan,Wrestling\nABBINGH Lois,Netherlands,Handball\nABBOT Emily,Australia,Rhythmic Gymnastics\nABBOTT Monica,United States of America,Baseball/Softball\nABDALLA Abubaker Haydar,Qatar,Athletics\nABDALLA Maryam,Egypt,Artistic Swimming\nABDALLAH Shahd,Egypt,Artistic Swimming\nABDALRASOOL Mohamed,Sudan,Judo\nABDEL LATIF Radwa,Egypt,Shooting\nABDEL RAZEK Samy,Egypt,Shooting\nABDELAZIZ Abdalla,Egypt,Karate\nABDELAZIZ Farah,Egypt,Table Tennis\nABDELAZIZ Feryal,Egypt,Karate\nABDELMAWGOUD Mohamed,Egypt,Judo\nABDELMOTTALEB Diaaeldin Kamal Gouda,Egypt,Wrestling\nABDELRAHMAN Ihab,Egypt,Athletics\nABDELSALAM Mohamed,Egypt,Football\nABDELSALAM No
# ...

# %%
type(s3_obj)
# Out:
# str

# %%
import pandas as pd
from io import StringIO

# %%
data = StringIO(s3_obj)

# %%
data2 = StringIO(s3_obj2)

# %%
s3_obj2
# Out:
# ''

# %%
df = pd.read_csv(data, delimiter=",")

# %%
df2 = pd.read_csv(data2, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df2 = pd.read_csv(data2, delimiter=",")
#
# File ~/Desktop/test_local_pyspark_etl/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#                   PersonName  Country           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [11085 rows x 3 columns]

# %%
df['PersonName']
# Out:
# 0              AALERUD Katrine
# 1                  ABAD Nestor
# 2            ABAGNALE Giovanni
# 3               ABALDE Alberto
# 4                ABALDE Tamara
#                  ...
# 11080    ZWICKER Martin Detlef
# 11081        ZWOLINSKA Klaudia
# 11082             ZYKOVA Yulia
# 11083        ZYUZINA Ekaterina
# 11084          ZYZANSKA Sylwia
# Name: PersonName, Length: 11085, dtype: object

# %%
df_short = df.tail(100)

# %%
df_short
# Out:
#                   PersonName                     Country    Discipline
# 10985              ZEZE Ryan                      France     Athletics
# 10986           ZGANK Mihael                      Turkey          Judo
# 10987        ZHADRAYEV Demeu                  Kazakhstan     Wrestling
# 10988              ZHAI Ying  People's Republic of China    Water Polo
# 10989           ZHANG Beiwen    United States of America     Badminton
# ...                      ...                         ...           ...
# 11080  ZWICKER Martin Detlef                     Germany        Hockey
# 11081      ZWOLINSKA Klaudia                      Poland  Canoe Slalom
# 11082           ZYKOVA Yulia                         ROC      Shooting
# 11083      ZYUZINA Ekaterina                         ROC       Sailing
# 11084        ZYZANSKA Sylwia                      Poland       Archery
#
# [100 rows x 3 columns]

# %%
sparkDF = spark.createDataFrame(df)

# %%
sparkDF
# Out:
# DataFrame[PersonName: string, Country: string, Discipline: string]

# %%
sparkDF.printSchema()
# Out:
# root
#  |-- PersonName: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Discipline: string (nullable = true)

# %%
testsparkDF = sparkDF()
# Out:
# +--------------------+--------------------+-------------------+
# |          PersonName|             Country|         Discipline|
# +--------------------+--------------------+-------------------+
# |     AALERUD Katrine|              Norway|       Cycling Road|
# |         ABAD Nestor|               Spain|Artistic Gymnastics|
# |   ABAGNALE Giovanni|               Italy|             Rowing|
# |      ABALDE Alberto|               Spain|         Basketball|
# |       ABALDE Tamara|               Spain|         Basketball|
# |           ABALO Luc|              France|           Handball|
# |        ABAROA Cesar|               Chile|             Rowing|
# |       ABASS Abobakr|               Sudan|           Swimming|
# |    ABBASALI Hamideh|Islamic Republic ...|             Karate|
# |       ABBASOV Islam|          Azerbaijan|          Wrestling|
# |        ABBINGH Lois|         Netherlands|           Handball|
# |         ABBOT Emily|           Australia|Rhythmic Gymnastics|
# ...
